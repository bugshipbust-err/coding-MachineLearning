# %%
import torch
from torch import einsum
from torch.linalg import eig, eigh
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
def plot_tensors_3d(tensor):
    def prepare_tensor(tensor):
        tensor = tensor.numpy() if isinstance(tensor, torch.Tensor) else tensor
        
        if tensor.ndim != 2:
            raise ValueError("Tensors must be 2D arrays.")
        if tensor.shape[1] < 3:
            padding = np.zeros((tensor.shape[0], 3 - tensor.shape[1]))
            tensor = np.hstack((tensor, padding))
        
        return tensor

    
    tensor = prepare_tensor(tensor)

    if tensor.shape[1] != 3:
        raise ValueError("Both tensors must have 3 columns (3 dimensions) after padding.")
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(tensor[:, 0], tensor[:, 1], tensor[:, 2], c='r', marker='o')

    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    ax.legend()
    plt.show()

# %%
x = torch.tensor([[2, -3, 2],
                  [-3, 0, 1]], dtype=torch.float32)

# %%
sl, sr = x@x.T, x.T@x

# %%
eigh(sl)[1], eigh(sr)[1]
# Out:
# (tensor([[-0.4132, -0.9106],
#          [-0.9106,  0.4132]]),
#  tensor([[ 0.2417,  0.6660, -0.7057],
#          [ 0.6447,  0.4333,  0.6298],
#          [ 0.7252, -0.6072, -0.3246]]))

# %%
eigval_sl, eigvec_sl = eigh(sl)
eigval_sr, eigvec_sr = eigh(sr)

# %%
def ortho_test(eigvec):
    for i in range(len(eigvec)):
        for j in range(len(eigvec)):
            dot_prod = eigvec.T[i] @ eigvec.T[j].T
            if (dot_prod < 1.0e-8):
                print(0, end=" ")
            else:
                print(int(dot_prod), end=" ")
        print()
    print()

# %%
ortho_test(eigvec_sl)
ortho_test(eigvec_sr)
# Out:
# 1 0
# 0 1
#
# 1 0 0
# 0 1 0
# 0 0 1

# %%
plot_tensors_3d(eigvec_sr.T)
# Out:
# /tmp/ipykernel_5676/3353280062.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
from VisualizationUtil import show_transform_3d

# %%
eigvec_sr
# Out:
# tensor([[ 0.2417,  0.6660, -0.7057],
#         [ 0.6447,  0.4333,  0.6298],
#         [ 0.7252, -0.6072, -0.3246]])

# %%
show_transform_3d(eigval_sr.T)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 show_transform_3d(eigval_sr.T)
#
# File ~/Documents/vscode/coding-MachineLearning/VisualizationUtil.py:110, in show_transform_3d(matrix, grid_size, show_base, size)
#     108     for y in y_vals:
#     109         transformed_line = matrix @ np.array([[x, x], [y, y], [-1, 1]])
# --> 110         ax.plot(transformed_line[0], transformed_line[1], transformed_line[2], color='red', alpha=0.5)
#     112 for y in y_vals:
#     113     for z in z_vals:
#
# IndexError: index 2 is out of bounds for dimension 0 with size 2
